# %% [markdown]
# ## ML Project: Texas House Price Prediction P1

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
# graph style
sns.set_theme()

# %% [markdown]
# ### Business Requirement

# %% [markdown]
# For this project, the number of houses will be considered to analyse its characteristics to find the best house prices. We will use the house dataset from the state of Texas. The state of Texas counts 5894 houses that are located. For each row of the dataset represents the house that are for sale although the column of the datasets are considered as features that describe the current condition of the house.

# %% [markdown]
# ### Problem Statement

# %% [markdown]
# The goal of this project is to find the best model that predicts the best house prices in texas based the input data to improve decision-making on the house prices.

# %%
housing_data = pd.read_csv("American_Housing_Data_20231209.csv")
housing_data.head()
# Out:
#    Zip Code      Price  Beds  Baths  Living Space                Address  \
# 0     10013  3999000.0     2      3          1967      74 GRAND ST APT 3
# 1     10013  3999000.0     2      3          1967      74 GRAND ST APT 3
# 2     10014  1650000.0     1      1           718  140 CHARLES ST APT 4D
# 3     10014   760000.0     3      2          1538            38 JONES ST
# 4     10014  1100000.0     1      1           600   81 BEDFORD ST APT 3F
#
#        City     State  Zip Code Population  Zip Code Density    County  \
# 0  New York  New York                29563           20967.9  New York
# 1  New York  New York                29563           20967.9  New York
# 2  New York  New York                29815           23740.9  New York
# 3  New York  New York                29815           23740.9  New York
# 4  New York  New York                29815           23740.9  New York
#
#    Median Household Income  Latitude  Longitude
# 0                 370046.0  40.72001  -74.00472
# 1                 370046.0  40.72001  -74.00472
# 2                 249880.0  40.73407  -74.00601
# 3                 249880.0  40.73407  -74.00601
# 4                 249880.0  40.73407  -74.00601

# %%
# identify dataset
housing_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39981 entries, 0 to 39980
# Data columns (total 14 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Zip Code                 39981 non-null  int64
#  1   Price                    39981 non-null  float64
#  2   Beds                     39981 non-null  int64
#  3   Baths                    39981 non-null  int64
#  4   Living Space             39981 non-null  int64
#  5   Address                  39981 non-null  object
#  6   City                     39981 non-null  object
#  7   State                    39981 non-null  object
#  8   Zip Code Population      39981 non-null  int64
#  9   Zip Code Density         39981 non-null  float64
#  10  County                   39981 non-null  object
#  11  Median Household Income  39979 non-null  float64
#  12  Latitude                 39981 non-null  float64
#  13  Longitude                39981 non-null  float64
# dtypes: float64(5), int64(5), object(4)
# memory usage: 4.3+ MB

# %%
# summary statistics
housing_data.describe()
# Out:
#            Zip Code         Price          Beds         Baths  Living Space  \
# count  39981.000000  3.998100e+04  39981.000000  39981.000000  39981.000000
# mean   64833.391336  6.227771e+05      3.171682      2.466572   1901.522723
# std    25614.601116  9.469793e+05      1.308796      1.323042   1211.307257
# min    10013.000000  1.800000e+03      1.000000      1.000000      2.000000
# 25%    40215.000000  2.650000e+05      3.000000      2.000000   1200.000000
# 50%    74136.000000  3.999000e+05      3.000000      2.000000   1639.000000
# 75%    85730.000000  6.749900e+05      4.000000      3.000000   2265.000000
# max    98199.000000  3.800000e+07     54.000000     66.000000  74340.000000
#
#        Zip Code Population  Zip Code Density  Median Household Income  \
# count         39981.000000      39981.000000             39979.000000
# mean          37726.201996       2379.412483            110837.259861
# std           18672.647445       2946.574792             47309.055715
# min               0.000000          0.000000             27475.000000
# 25%           24465.000000        902.400000             76640.000000
# 50%           35049.000000       1588.700000            100405.000000
# 75%           46816.000000       2736.800000            135075.000000
# max          116469.000000      58289.600000            900203.000000
#
#            Latitude     Longitude
# count  39981.000000  39981.000000
# mean      36.435668    -98.080576
# std        4.446862     15.061145
# min       25.729830   -122.826870
# 25%       33.239850   -111.636310
# 50%       36.166620    -96.839680
# 75%       39.283090    -85.656980
# max       47.742370    -73.704510

# %% [markdown]
# ## Texas Housing Dataset: Data analysis

# %%
# retrieve all houses for the state of texas
texas_housing = housing_data[housing_data["State"] == "Texas"]
texas_housing.head()
# Out:
#        Zip Code      Price  Beds  Baths  Living Space  \
# 20126     75051   394900.0     3      2          1529
# 20127     75051   414900.0     5      4          2376
# 20128     75201  2995000.0     3      4          3415
# 20129     75201   650000.0     2      2          1507
# 20130     75201   469000.0     2      3          2045
#
#                           Address           City  State  Zip Code Population  \
# 20126               1954 BEACH DR  Grand Prairie  Texas                39783
# 20127                 1947 PEZ DR  Grand Prairie  Texas                39783
# 20128  3130 N HARWOOD ST APT 1406         Dallas  Texas                17491
# 20129     511 N AKARD ST APT 1503         Dallas  Texas                17491
# 20130        1505 ELM ST APT 1203         Dallas  Texas                17491
#
#        Zip Code Density  County  Median Household Income  Latitude  Longitude
# 20126            1216.6  Dallas                  63560.0  32.72635  -96.99375
# 20127            1216.6  Dallas                  63560.0  32.72635  -96.99375
# 20128            4907.2  Dallas                 149296.0  32.78826  -96.79953
# 20129            4907.2  Dallas                 149296.0  32.78826  -96.79953
# 20130            4907.2  Dallas                 149296.0  32.78826  -96.79953

# %%
# identify texas dataset
def identify_texas_data(texas_data):
  texas_data_size = texas_data.size
  texas_data_shape = texas_data.shape
  return (texas_data_size, texas_data_shape)

# %%
texas_data_id = identify_texas_data(texas_housing)
print(f"Texas dataset - size: {texas_data_id[0]}")
print(f"Texas dataset - shape: {texas_data_id[1]}")
print(f"\t - number of houses: {texas_data_id[1][0]} houses")
print(f"\t - number of house features: {texas_data_id[1][1]} features")
# Out:
# Texas dataset - size: 82516
# Texas dataset - shape: (5894, 14)
# 	 - number of houses: 5894 houses
# 	 - number of house features: 14 features

# %%
# identify datatypes for each feature
texas_housing.dtypes
# Out:
# Zip Code                     int64
# Price                      float64
# Beds                         int64
# Baths                        int64
# Living Space                 int64
# Address                     object
# City                        object
# State                       object
# Zip Code Population          int64
# Zip Code Density           float64
# County                      object
# Median Household Income    float64
# Latitude                   float64
# Longitude                  float64
# dtype: object

# %% [markdown]
# ### Data Preprocessing

# %%
# identify duplicated samples
num_duplicated_samples = texas_housing.duplicated().sum() # 88 duplicated sample
print(f"Number of duplicated rows after removing: {num_duplicated_samples}")
print(f"Number of Samples before removing: {texas_housing.shape}")
# Out:
# Number of duplicated rows after removing: 88
# Number of Samples before removing: (5894, 14)

# %%
texas_housing = texas_housing.drop_duplicates()
num_duplicated_samples = texas_housing.duplicated().sum()
print(f"Number of duplicated rows after removing: {num_duplicated_samples}")
print(f"Number of Samples before removing: {texas_housing.shape}")
# Out:
# Number of duplicated rows after removing: 0
# Number of Samples before removing: (5806, 14)

# %%
# identify nullvalues
texas_housing.isnull().sum() # no null values
# Out:
# Zip Code                   0
# Price                      0
# Beds                       0
# Baths                      0
# Living Space               0
# Address                    0
# City                       0
# State                      0
# Zip Code Population        0
# Zip Code Density           0
# County                     0
# Median Household Income    0
# Latitude                   0
# Longitude                  0
# dtype: int64

# %%
# modify price data from place to new place
price_data = texas_housing["Price"]
texas_housing = texas_housing.drop(columns=["Price"])
texas_housing = pd.concat([texas_housing, price_data], axis=1)
texas_housing.head()
# Out:
#        Zip Code  Beds  Baths  Living Space                     Address  \
# 20126     75051     3      2          1529               1954 BEACH DR
# 20127     75051     5      4          2376                 1947 PEZ DR
# 20128     75201     3      4          3415  3130 N HARWOOD ST APT 1406
# 20129     75201     2      2          1507     511 N AKARD ST APT 1503
# 20130     75201     2      3          2045        1505 ELM ST APT 1203
#
#                 City  State  Zip Code Population  Zip Code Density  County  \
# 20126  Grand Prairie  Texas                39783            1216.6  Dallas
# 20127  Grand Prairie  Texas                39783            1216.6  Dallas
# 20128         Dallas  Texas                17491            4907.2  Dallas
# 20129         Dallas  Texas                17491            4907.2  Dallas
# 20130         Dallas  Texas                17491            4907.2  Dallas
#
#        Median Household Income  Latitude  Longitude      Price
# 20126                  63560.0  32.72635  -96.99375   394900.0
# 20127                  63560.0  32.72635  -96.99375   414900.0
# 20128                 149296.0  32.78826  -96.79953  2995000.0
# 20129                 149296.0  32.78826  -96.79953   650000.0
# 20130                 149296.0  32.78826  -96.79953   469000.0

# %% [markdown]
# ### Exploratory Data Analysis

# %% [markdown]
# Objective of Exploratory Data analysis
# + create a numeric and categorical distribution
# + finding for possible outliers per feature

# %%
# numeric distribution
texas_feature_list = texas_housing.columns
def create_num_dataset(texas_data, feature_list):
  # create list that stores all numeric feature from the actual feature list
  num_feature_list = []
  # iterate the feature and check whether its data type is considered as integer or float
  for feature in feature_list:
    feature_int = pd.api.types.is_integer_dtype(texas_data[feature])
    feature_float = pd.api.types.is_float_dtype(texas_data[feature])
    if feature_int or feature_float:
      num_feature_list.append(feature)

  # plot num_distribution
  texas_data2 = texas_data[num_feature_list]
  return texas_data2

# %%
tex_num_data = create_num_dataset(texas_housing, texas_feature_list)
tex_num_data.index = list(range(0,texas_housing.shape[0]))
tex_num_data
# Out:
#       Zip Code  Beds  Baths  Living Space  Zip Code Population  \
# 0        75051     3      2          1529                39783
# 1        75051     5      4          2376                39783
# 2        75201     3      4          3415                17491
# 3        75201     2      2          1507                17491
# 4        75201     2      3          2045                17491
# ...        ...   ...    ...           ...                  ...
# 5801     79938     4      3          1664                91575
# 5802     79938     3      2          1579                91575
# 5803     79938     4      3          1825                91575
# 5804     79938     4      3          2811                91575
# 5805     79938     4      3          1866                91575
#
#       Zip Code Density  Median Household Income  Latitude  Longitude  \
# 0               1216.6                  63560.0  32.72635  -96.99375
# 1               1216.6                  63560.0  32.72635  -96.99375
# 2               4907.2                 149296.0  32.78826  -96.79953
# 3               4907.2                 149296.0  32.78826  -96.79953
# 4               4907.2                 149296.0  32.78826  -96.79953
# ...                ...                      ...       ...        ...
# 5801              90.6                  86064.0  31.85764 -106.03895
# 5802              90.6                  86064.0  31.85764 -106.03895
# 5803              90.6                  86064.0  31.85764 -106.03895
# 5804              90.6                  86064.0  31.85764 -106.03895
# 5805              90.6                  86064.0  31.85764 -106.03895
#
#           Price
# 0      394900.0
# 1      414900.0
# 2     2995000.0
# 3      650000.0
# 4      469000.0
# ...         ...
# 5801   274500.0
# 5802   252835.0
# 5803   350950.0
# 5804   279950.0
# 5805   361950.0
#
# [5806 rows x 10 columns]

# %%
beds_max = tex_num_data["Beds"].max()
beds_min = tex_num_data["Beds"].min()
print(f"Number of beds: ")
print(f"\t - minimal amount: {beds_min}")
print(f"\t - maximal amount: {beds_max}")
# Out:
# Number of beds:
# 	 - minimal amount: 1
# 	 - maximal amount: 34

# %%
# visualise numeric distribution plot
num_features = tex_num_data.shape[1]
num_cols = 4
num_rows = (num_features + num_cols - 1) // num_cols
print(num_cols)

# create subplot
fig, dist = plt.subplots(num_rows, num_cols, figsize=(16,12))
# Flatten axes array for easy iteration if necessary
distplots = dist.flatten()
# Iterate over the features and plot the histogram
for i, col in enumerate(tex_num_data.columns):
  distplots[i].hist(tex_num_data[col], bins=20, alpha=0.7, color="green")
  distplots[i].set_title(col)
  
  # sns.histplot(data=tex_num_data, x="Beds", binwidth=3, dist[i,j])

# If there are more subplots than features, hide the empty subplots
for j in range(i + 1, len(distplots)):
    fig.delaxes(distplots[j])
# Out:
# 4

# %%
# categorical distribution
txs_county_data = texas_housing["County"].value_counts().to_frame(name="Number of Houses")
txs_county_data = txs_county_data.reset_index().rename(columns={"index": "County"})
txs_county_data
# Out:
#         County  Number of Houses
# 0      Tarrant              1564
# 1        Bexar               865
# 2       Dallas               835
# 3      El Paso               820
# 4       Travis               810
# 5       Harris               789
# 6   Williamson                33
# 7       Collin                29
# 8         Hays                17
# 9       Denton                14
# 10   Fort Bend                11
# 11     Johnson                 9
# 12      Parker                 8
# 13     Kendall                 1
# 14    Atascosa                 1

# %%
num_pop = texas_housing["Zip Code Population"]
county_pop_data = texas_housing.groupby("County")[["Zip Code Population"]].sum().reset_index()
county_pop_data = txs_county_data.merge(county_pop_data, on="County")
county_pop_data.head()
# Out:
#     County  Number of Houses  Zip Code Population
# 0  Tarrant              1564             60504613
# 1    Bexar               865             39067954
# 2   Dallas               835             30538583
# 3  El Paso               820             51604894
# 4   Travis               810             27006692

# %%
# visualise categorical variable using plotly
px.bar(data_frame=county_pop_data, x="County", y="Number of Houses", 
       title="Number of Houses per County", 
       color_discrete_sequence=["Green"]*14, opacity=0.75,
       hover_data=["Number of Houses"],
       labels="Houses")

# %% [markdown]
# ### Correlation Analysis P1

# %%
# create correlation table
texas_corr_data = tex_num_data.corr()

# visualise using heatmap
plt.figure(figsize=(14,6))
sns.heatmap(data=texas_corr_data, annot=True, cmap="Greens")
plt.title("Heatmap of House features Part 1", fontsize=20)
plt.xticks(rotation=30)
plt.show()

# %% [markdown]
# According to the heatmap, the best features for this problem that help to predict the best house prices are:
# + Beds: r= 0.28
# + Baths: r=0.58
# + Living Space: r=0.68
# + Median Household Income: r=0.49
# + Longitude: r=0.13

# %% [markdown]
# ### Feature Engineering

# %% [markdown]
# In this stage, we will be selecting the numeric features that the describe the best of our house prices.
#
# - feature scaling
# - feature engineering
# - feature selection for modeling

# %%
feature_data = tex_num_data[:]
feature_data.head()
# Out:
#    Zip Code  Beds  Baths  Living Space  Zip Code Population  Zip Code Density  \
# 0     75051     3      2          1529                39783            1216.6
# 1     75051     5      4          2376                39783            1216.6
# 2     75201     3      4          3415                17491            4907.2
# 3     75201     2      2          1507                17491            4907.2
# 4     75201     2      3          2045                17491            4907.2
#
#    Median Household Income  Latitude  Longitude      Price
# 0                  63560.0  32.72635  -96.99375   394900.0
# 1                  63560.0  32.72635  -96.99375   414900.0
# 2                 149296.0  32.78826  -96.79953  2995000.0
# 3                 149296.0  32.78826  -96.79953   650000.0
# 4                 149296.0  32.78826  -96.79953   469000.0

# %%
# feature engineering
# Price                                 reduce 10**3 to 1k 
# Household income                      reduce to 1k          900 203 --> 900.02k dollar
# Living Space                          convert to m2
# Zip code population                   reduce to 1k
feature_data.loc[:, ["Price(1k)"]] = feature_data["Price"]/1000
feature_data.loc[:, ["Median Household Income(1k)"]] = feature_data["Median Household Income"]/1000
living_space_sqf = 0.092903 # in sqm: in squared metres
feature_data.loc[:, ["Area Living Space(sqm)"]] = feature_data["Living Space"]*living_space_sqf

# drop unnecessary columns
feature_data = feature_data.drop(columns=["Price"], axis=1)
feature_data = feature_data.drop(columns=["Median Household Income"], axis=1)
feature_data = feature_data.drop(columns=["Living Space"], axis=1)
feature_data.head()
# Out:
# C:\Users\mian_\AppData\Local\Temp\ipykernel_22484\1005425536.py:6: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\mian_\AppData\Local\Temp\ipykernel_22484\1005425536.py:7: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\mian_\AppData\Local\Temp\ipykernel_22484\1005425536.py:9: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#    Zip Code  Beds  Baths  Zip Code Population  Zip Code Density  Latitude  \
# 0     75051     3      2                39783            1216.6  32.72635
# 1     75051     5      4                39783            1216.6  32.72635
# 2     75201     3      4                17491            4907.2  32.78826
# 3     75201     2      2                17491            4907.2  32.78826
# 4     75201     2      3                17491            4907.2  32.78826
#
#    Longitude  Price(1k)  Median Household Income(1k)  Area Living Space(sqm)
# 0  -96.99375      394.9                       63.560              142.048687
# 1  -96.99375      414.9                       63.560              220.737528
# 2  -96.79953     2995.0                      149.296              317.263745
# 3  -96.79953      650.0                      149.296              140.004821
# 4  -96.79953      469.0                      149.296              189.986635

# %%
# # price/bedrooms
# # price/bathrooms
# price/living space
# feature_data["Price_p_bed(1k/bed)"] = feature_data["Price(1k)"]/feature_data["Beds"] # drop
# feature_data["Price_p_bath(1k/bath)"] = feature_data["Price(1k)"]/feature_data["Baths"] # drop
feature_data["Price_p_living"] = feature_data["Price(1k)"]/feature_data["Area Living Space(sqm)"]

# show feature data
feature_data.head()
# Out:
#    Zip Code  Beds  Baths  Zip Code Population  Zip Code Density  Latitude  \
# 0     75051     3      2                39783            1216.6  32.72635
# 1     75051     5      4                39783            1216.6  32.72635
# 2     75201     3      4                17491            4907.2  32.78826
# 3     75201     2      2                17491            4907.2  32.78826
# 4     75201     2      3                17491            4907.2  32.78826
#
#    Longitude  Price(1k)  Median Household Income(1k)  Area Living Space(sqm)  \
# 0  -96.99375      394.9                       63.560              142.048687
# 1  -96.99375      414.9                       63.560              220.737528
# 2  -96.79953     2995.0                      149.296              317.263745
# 3  -96.79953      650.0                      149.296              140.004821
# 4  -96.79953      469.0                      149.296              189.986635
#
#    Price_p_living
# 0        2.780033
# 1        1.879608
# 2        9.440095
# 3        4.642697
# 4        2.468595

# %%
# feature engineering part 2
# bathroom/sqm
# bedroom/sqm

feature_data["Area_bath_sqm"] = feature_data["Area Living Space(sqm)"]/feature_data["Baths"]
feature_data["Area_bed_sqm"] = feature_data["Area Living Space(sqm)"]/feature_data["Beds"]
feature_data["Living_space"] = feature_data["Baths"] + feature_data["Beds"]

# %%
# modify price data location
price_data = feature_data["Price(1k)"]
feature_data = feature_data.drop(columns=["Price(1k)"], axis=1)
feature_data = pd.concat([feature_data, price_data], axis=1)
feature_data.head()
# Out:
#    Zip Code  Beds  Baths  Zip Code Population  Zip Code Density  Latitude  \
# 0     75051     3      2                39783            1216.6  32.72635
# 1     75051     5      4                39783            1216.6  32.72635
# 2     75201     3      4                17491            4907.2  32.78826
# 3     75201     2      2                17491            4907.2  32.78826
# 4     75201     2      3                17491            4907.2  32.78826
#
#    Longitude  Median Household Income(1k)  Area Living Space(sqm)  \
# 0  -96.99375                       63.560              142.048687
# 1  -96.99375                       63.560              220.737528
# 2  -96.79953                      149.296              317.263745
# 3  -96.79953                      149.296              140.004821
# 4  -96.79953                      149.296              189.986635
#
#    Price_p_living  Area_bath_sqm  Area_bed_sqm  Living_space  Price(1k)
# 0        2.780033      71.024344     47.349562             5      394.9
# 1        1.879608      55.184382     44.147506             9      414.9
# 2        9.440095      79.315936    105.754582             7     2995.0
# 3        4.642697      70.002410     70.002410             4      650.0
# 4        2.468595      63.328878     94.993318             5      469.0

# %% [markdown]
# ### Correlation Analysis Part 2

# %%
# create correlation maps
feature_corr2 = feature_data.corr()
plt.figure(figsize=(16,10))

# visualise correlation map using heatmp
sns.heatmap(data=feature_corr2, annot=True, cmap="Greens")
plt.title("Heatmap of House features", fontsize=20)

# modify heatmap
plt.title("Heatmap of House features part 2", fontsize=20)
plt.xticks(rotation=30)
plt.show()

# %% [markdown]
# By featuring engineering, new features have just appeared in the 2nd heatmap that show a stronger correlation in comparison with the 1st heatmap.
# These features that will be considered for further analysis, are:
# + Area bath sqm
# + Area bed sqm
# + Price p living
# + Living Space
# + Median Household Income
# + Baths
# + Beds

# %%
features = ["Zip Code",'Beds', 'Baths','Median Household Income(1k)',
       'Area Living Space(sqm)', 'Price_p_living', 'Area_bath_sqm',
       'Living_space', 'Price(1k)']
feature_data.loc[:,features].corr("pearson")
# Out:
#                              Zip Code      Beds     Baths  \
# Zip Code                     1.000000  0.055212 -0.047150
# Beds                         0.055212  1.000000  0.596487
# Baths                       -0.047150  0.596487  1.000000
# Median Household Income(1k) -0.128609  0.092035  0.365070
# Area Living Space(sqm)      -0.094141  0.618585  0.815832
# Price_p_living               0.004407 -0.043973  0.105638
# Area_bath_sqm               -0.102354  0.194574 -0.120488
# Living_space                 0.001675  0.881991  0.904345
# Price(1k)                   -0.068298  0.277052  0.580154
#
#                              Median Household Income(1k)  \
# Zip Code                                       -0.128609
# Beds                                            0.092035
# Baths                                           0.365070
# Median Household Income(1k)                     1.000000
# Area Living Space(sqm)                          0.402430
# Price_p_living                                  0.254692
# Area_bath_sqm                                   0.108974
# Living_space                                    0.263294
# Price(1k)                                       0.490157
#
#                              Area Living Space(sqm)  Price_p_living  \
# Zip Code                                  -0.094141        0.004407
# Beds                                       0.618585       -0.043973
# Baths                                      0.815832        0.105638
# Median Household Income(1k)                0.402430        0.254692
# Area Living Space(sqm)                     1.000000        0.089275
# Price_p_living                             0.089275        1.000000
# Area_bath_sqm                              0.394771       -0.041981
# Living_space                               0.807961        0.038643
# Price(1k)                                  0.680209        0.394089
#
#                              Area_bath_sqm  Living_space  Price(1k)
# Zip Code                         -0.102354      0.001675  -0.068298
# Beds                              0.194574      0.881991   0.277052
# Baths                            -0.120488      0.904345   0.580154
# Median Household Income(1k)       0.108974      0.263294   0.490157
# Area Living Space(sqm)            0.394771      0.807961   0.680209
# Price_p_living                   -0.041981      0.038643   0.394089
# Area_bath_sqm                     1.000000      0.032721   0.185329
# Living_space                      0.032721      1.000000   0.487966
# Price(1k)                         0.185329      0.487966   1.000000

# %%
# feature selection for model training
feature_data.columns
feature_sel = ["Zip Code",'Beds', 'Baths','Median Household Income(1k)',
       'Area Living Space(sqm)', 'Price_p_living', 'Area_bath_sqm',
       'Living_space', 'Price(1k)']
model_training_data = feature_data[feature_sel]
model_training_data.head()
# Out:
#    Zip Code  Beds  Baths  Median Household Income(1k)  Area Living Space(sqm)  \
# 0     75051     3      2                       63.560              142.048687
# 1     75051     5      4                       63.560              220.737528
# 2     75201     3      4                      149.296              317.263745
# 3     75201     2      2                      149.296              140.004821
# 4     75201     2      3                      149.296              189.986635
#
#    Price_p_living  Area_bath_sqm  Living_space  Price(1k)
# 0        2.780033      71.024344             5      394.9
# 1        1.879608      55.184382             9      414.9
# 2        9.440095      79.315936             7     2995.0
# 3        4.642697      70.002410             4      650.0
# 4        2.468595      63.328878             5      469.0

# %%
# save model training dataset as csv-file
model_training_data.to_csv("texas_model_training_set.csv")
